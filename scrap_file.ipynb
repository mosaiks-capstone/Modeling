# %%
import geopandas as gpd

# specify the path to the shapefile
#filepath = "National/myshapefile.shp"

# read in the shapefile using geopandas
#gdf = gpd.read_file(filepath)

# %%
# Just trying to see what the issue is for the 2nd file in 2019
import pandas as pd
pd.read_feather("/capstone/mosaiks/repos/modeling/data/zambia_all_good/sentinel-2-l2a_bands-3-4-5_ZMB_62k-points_1000-features_2019_3.feather")
# Out:
#                   0    1         2         3         4         5         6  \
# 0      1.472132e-07  0.0  0.000722  0.149333  0.020724  0.000046  0.001081
# 1      6.734843e-04  0.0  0.002213  0.346202  0.023845  0.000012  0.000963
# 2      1.861001e-05  0.0  0.001243  0.299511  0.015322  0.000135  0.000165
# 3      0.000000e+00  0.0  0.000348  0.044901  0.005285  0.000000  0.000075
# 4      0.000000e+00  0.0  0.000398  0.013752  0.004317  0.000037  0.000084
# ...             ...  ...       ...       ...       ...       ...       ...
# 53298  0.000000e+00  0.0  0.000000  0.021147  0.006653  0.000000  0.000733
# 53299  0.000000e+00  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 53300  0.000000e+00  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 53301  0.000000e+00  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
# 53302  0.000000e+00  0.0  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...

# %%
# Check out Carlo's new features:
features = pd.read_feather("/capstone/mosaiks/repos/modeling/data/features_sea_save.feather")
features
# Out:
#         index         0         1         2         3         4         5  \
# 0           0  0.001570  0.000480  0.005897  1.353835  0.509915  0.002976
# 1           1  0.001463  0.000276  0.007684  0.980061  0.378347  0.001967
# 2           2  0.003168  0.000671  0.005166  0.726874  0.222981  0.002820
# 3           3  0.001240  0.000455  0.022193  1.314633  0.528798  0.002496
# 4           4  0.004002  0.000425  0.012011  0.937913  0.405020  0.002348
# ...       ...       ...       ...       ...       ...       ...       ...
# 918658   3729  0.000000  0.000000  0.003351  0.506587  0.075253  0.000000
# 918659   3730  0.000000  0.000000  0.001638  0.500491  0.068168  0.000000
# 918660   3731  0.000771  0.000000  0.003275  0.559318  0.070403  0.000192
# 918661   3732  0.000508  0.000003  0.003023  0.259634  0.059728  0.000642
# 918662   3733  0.003019  0.000000  0.000741  0.349308  0.096118  0.000000
#
#                6         7    8  ...       994       995       996       997  \
# ...

# %%
x, y = features.shape
x
# Out:
# 918663

# %%
len(features)
# Out:
# 918663
